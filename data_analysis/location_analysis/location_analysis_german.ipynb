# %% [markdown]
# # Location Analysis German

# %% [markdown]
# ### Setup

# %% [markdown]
# **Important imports**

# %%
import pandas as pd
import spacy
import requests
import time
import re
import unicodedata

# %%
nlp = spacy.load("de_core_news_sm")

# %%
df_german = pd.read_csv('../../scraping/data/extractor_all_articles_20minuten.csv')
df_french = pd.read_csv('../../scraping/data/extractor_all_articles_20minutes.csv')

# %%
german_iso_3166 = pd.read_csv('inputdata/german-iso-3166.csv', names=['ISO2', 'Name'])
english_iso_3166 = pd.read_csv('inputdata/english-iso-3166.csv', usecols=['alpha-2', 'name', 'alpha-3'])
english_iso_3166.columns = ['Name', 'ISO2', 'ISO3']

# %% [markdown]
# **Loading dataframes and cleaning them**

# %%
def normalize_text(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii').lower()

# %%
def apply_normalize_text_if_str(x):
    return normalize_text(x) if isinstance(x, str) else x

# %%
def lowercase_columns(df, columns):
    for column in columns:
        df[column] = df[column].str.lower()

# %%
columns_to_normalize = ['Content', 'Title', 'Header']
df_german[columns_to_normalize] = df_german[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
df_countries_german = pd.read_csv('inputdata/country_capital_german.csv')
columns_to_lower = ['Staat', 'Hauptstadt', 'Kontinent']
lowercase_columns(df_countries_german, columns_to_lower)

# %%
df_cities_german = pd.read_csv('inputdata/listestaedte_schweiz.csv')
df_cities_german['Name'] = df_cities_german['Name'].apply(lambda x: normalize_text(x) if isinstance(x, str) else x)

# %%
df_cantons_german = pd.read_csv('inputdata/kantone.csv')
df_cantons_german['Kanton'] = df_cantons_german['Kanton'].apply(lambda x: normalize_text(x) if isinstance(x, str) else x)

# %% [markdown]
# ### Add Coordinates Functionality

# %%
geocode_api_key = '1983e85e9a97673a09ed6d19417dda0f'

# %%
def geocode_location_positionstack(location_name, api_key):
    base_url = "http://api.positionstack.com/v1/forward"
    params = {
        'access_key': api_key,
        'query': location_name,
        'limit': 1,
    }
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data['data']:
            latitude = data['data'][0]['latitude']
            longitude = data['data'][0]['longitude']
            return latitude, longitude
        else:
            return None, None
    else:
        print(f"Error: {response.status_code}")
        return None, None

# %%
def add_coordinates(row):
    lat, lng = geocode_location_positionstack(row['Name'], geocode_api_key)
    return pd.Series({'Coordinates': (lat, lng), 'Latitude': lat, 'Longitude': lng})

# %%
def add_coordinates(row, column_name, api_key):
    location_name = row[column_name]
    lat, lng = geocode_location_positionstack(location_name, api_key)
    return pd.Series({'Coordinates': (lat, lng), 'Latitude': lat, 'Longitude': lng})

# %% [markdown]
# **Add coordinates to cities in Switzerland**

# %%
#df_cities_german[['Coordinates', 'Latitude', 'Longitude']] = df_cities_german.apply(add_coordinates, axis=1)
df_cities_german[['Coordinates', 'Latitude', 'Longitude']] = df_cities_german.apply(lambda row: add_coordinates(row, 'Name', geocode_api_key), axis=1)

# %%
indices_with_none = df_cities_german[df_cities_german['Coordinates'] == (None, None)].index

# %%
for idx in indices_with_none:
    city_name = df_cities_german.loc[idx, 'Name']
    print(f"Attempting to geocode: {city_name}") 
    try:

        time.sleep(1)
        
        new_coords = geocode_location_positionstack(city_name, geocode_api_key)
        print(f"Coordinates received: {new_coords}")  
        
        if new_coords is None or len(new_coords) != 2:
            raise ValueError(f"Invalid coordinates received: {new_coords}")
        
        df_cities_german.loc[idx, 'Latitude'] = new_coords[0]
        df_cities_german.loc[idx, 'Longitude'] = new_coords[1]

        df_cities_german.at[idx, 'Coordinates'] = (new_coords[0], new_coords[1])

    except Exception as e:
        print(f"Error geocoding {city_name}: {e}")
        traceback.print_exc() 
        df_cities_german.loc[idx, ['Latitude', 'Longitude']] = [None, None]
        df_cities_german.at[idx, 'Coordinates'] = (None, None)
# Out:
# Attempting to geocode: val-de-travers ne
# Coordinates received: (46.917395, 6.588048)
# Attempting to geocode: sarnen ⁠
# Coordinates received: (46.895035, 8.248186)
# Attempting to geocode: flawil
# Coordinates received: (47.41568, 9.189439)
# Attempting to geocode: neuhausen am rheinfall
# Coordinates received: (47.682077, 8.612612)
# Attempting to geocode: aigle ⁠
# Coordinates received: (46.317669, 6.970125)
# Attempting to geocode: lutry ⁠
# Coordinates received: (46.503453, 6.686783)
# Attempting to geocode: birsfelden
# Coordinates received: (47.550784, 7.636283)
# Attempting to geocode: sursee ⁠
# Coordinates received: (47.175697, 8.10871)
# Attempting to geocode: aesch
# Coordinates received: (47.47104, 7.5973)
# Attempting to geocode: naters
# Coordinates received: (46.326545, 7.987857)
# Attempting to geocode: gossau
# Coordinates received: (47.411712, 9.251598)
# Attempting to geocode: bernex
# Coordinates received: (46.174748, 6.077743)
# Attempting to geocode: münchenbuchsee
# Coordinates received: (47.022114, 7.451819)
# Attempting to geocode: crans-montana
# Coordinates received: (46.31316, 7.47914)
# Attempting to geocode: wald
# Coordinates received: (47.27259, 8.914172)
# Attempting to geocode: steinhausen
# Coordinates received: (47.195526, 8.478206)
# Attempting to geocode: payerne ⁠
# Coordinates received: (46.820755, 6.938857)
# Attempting to geocode: urdorf
# Coordinates received: (47.370339, 8.425088)

# %% [markdown]
# **Add coordinates to capital cities worldwide**

# %%
df_countries_german[['Coordinates', 'Latitude', 'Longitude']] = df_countries_german.apply(lambda row: add_coordinates(row, 'Hauptstadt', geocode_api_key), axis=1)

# %% [markdown]
# ### Search Functions

# %% [markdown]
# #### Country Search

# %%
def find_countries_in_text(content, header, country_data, swiss_cities, swiss_cantons):
    combined_text = str(content) + " " + str(header)
    doc = nlp(combined_text)
    mentioned_countries = set()

    for ent in doc.ents:
        if ent.label_ in ['LOC', 'GPE']:

            if ent.text.lower() in swiss_cities['Name'].str.lower().values or ent.text.lower() in swiss_cantons['Kanton'].str.lower().values:
                mentioned_countries.add("Schweiz")
                continue  

            country_from_capital = country_data[country_data['Hauptstadt'].str.lower() == ent.text.lower()]['Staat']
            if not country_from_capital.empty:
                mentioned_countries.add(country_from_capital.iloc[0])
                continue 

            country = country_data[country_data['Staat'].str.lower() == ent.text.lower()]['Staat']
            if not country.empty:
                mentioned_countries.add(country.iloc[0])

    return mentioned_countries

# %%
df_german['Mentioned_Countries'] = df_german.apply(lambda row: find_countries_in_text(row['Content'], row['Header'], df_countries_german, df_cities_german, df_cantons_german), axis=1)

# %% [markdown]
# #### Count Country Mentions

# %%
country_counts = df_german.explode('Mentioned_Countries')['Mentioned_Countries'].value_counts()
df_country_counts = pd.DataFrame({'Country': country_counts.index, 'Count': country_counts.values})
df_country_counts.sort_values(by='Count', ascending=False, inplace=True)

# %%
df_countries_german
# Out:
#              Staat        Hauptstadt Kontinent             Coordinates  \
# 0      Afghanistan             Kabul     Asien    (34.52813, 69.17233)
# 1          Ägypten             Kairo    Afrika  (30.079694, 31.323437)
# 2         Albanien            Tirana    Europa  (41.282045, 19.799067)
# 3         Algerien            Algier    Afrika    (36.74395, 3.083627)
# 4          Andorra  Andorra la Vella    Europa   (42.504294, 1.518714)
# ..             ...               ...       ...                     ...
# 205    Südossetien         Zchinwali       NaN    (42.22764, 43.96861)
# 206         Taiwan            Taipeh       NaN   (25.04776, 121.53185)
# 207  Transnistrien          Tiraspol       NaN  (46.848936, 29.630367)
# 208    Westsahara           El Aaiún       NaN   (27.16224, -13.20315)
# 209     Westsahara          Tifariti       NaN    (26.1579, -10.55889)
#
#       Latitude   Longitude
# 0    34.528130   69.172330
# 1    30.079694   31.323437
# 2    41.282045   19.799067
# 3    36.743950    3.083627
# 4    42.504294    1.518714
# ..         ...         ...
# 205  42.227640   43.968610
# 206  25.047760  121.531850
# 207  46.848936   29.630367
# 208  27.162240  -13.203150
# 209  26.157900  -10.558890
#
# [210 rows x 6 columns]

# %%
df_country_count_data = df_country_counts.merge(df_countries_german, left_on='Country', right_on='Staat', how='left')
df_country_count_data = df_country_count_data[['Country', 'Count', 'Hauptstadt', 'Coordinates', 'Latitude', 'Longitude']]

# %%
df_country_count_data
# Out:
#                            Country  Count Hauptstadt             Coordinates  \
# 0                          Schweiz    315       Bern   (46.946416, 7.396394)
# 1                      Deutschland     69     Berlin  (52.524932, 13.407032)
# 2                           Israel     49  Jerusalem  (31.759595, 35.215315)
# 3                          Italien     34        Rom  (41.878243, 12.528091)
# 4                       Frankreich     32      Paris   (48.858705, 2.342865)
# ..                             ...    ...        ...                     ...
# 98                           Sudan      1    Khartum    (15.55177, 32.53241)
# 99                        Mosambik      1     Maputo   (-25.96553, 32.58322)
# 100                       Lettland      1       Riga  (56.971149, 24.142749)
# 101                     Mazedonien      1     Skopje    (42.00122, 21.42878)
# 102  Kongo, Demokratische Republik      1   Kinshasa    (-4.32142, 15.30807)
#
#       Latitude  Longitude
# 0    46.946416   7.396394
# 1    52.524932  13.407032
# 2    31.759595  35.215315
# 3    41.878243  12.528091
# 4    48.858705   2.342865
# ..         ...        ...
# 98   15.551770  32.532410
# 99  -25.965530  32.583220
# 100  56.971149  24.142749
# 101  42.001220  21.428780
# 102  -4.321420  15.308070
#
# [103 rows x 6 columns]

# %% [markdown]
# **Add translation so that we have German and English Names (based on ISO Codes)**

# %%
df_final_country_count_data = df_country_count_data.merge(german_iso_3166, left_on='Country', right_on='Name', how='left')
df_final_country_count_data = df_final_country_count_data[['Country', 'ISO2', 'Count', 'Hauptstadt', 'Coordinates', 'Longitude', 'Latitude']]

# %%
df_final_country_count_data = df_final_country_count_data.merge(english_iso_3166, on='ISO2', how='left')

# Rename the 'Name' column from english_iso_3166 to 'EnglishName'
df_final_country_count_data.rename(columns={'Name': 'EnglishName'}, inplace=True)
df_final_country_count_data.rename(columns={'Country': 'GermanName'}, inplace=True)
df_final_country_count_data.rename(columns={'Hauptstadt': 'Capital'}, inplace=True)

# %%
desired_columns = [
    'GermanName', 'Count', 'Coordinates', 'Longitude',
    'Latitude', 'ISO2', 'ISO3', 'EnglishName', 'Capital'
]

df_final_country_count_data = df_final_country_count_data[desired_columns]

# %% [markdown]
# #### City Search

# %%
def find_swiss_cities_in_text(content, header, df_cities_german):
    combined_text = normalize_text(str(content) + " " + str(header)).strip()
    mentioned_swiss_cities = set()

    for city in df_cities_german['Name']:
        normalized_city = normalize_text(city).strip()
        # Use a regular expression to find whole word matches only
        if re.search(r'\b' + re.escape(normalized_city) + r'\b', combined_text):
            mentioned_swiss_cities.add(city)

    return mentioned_swiss_cities

# %%
df_german['Mentioned_Swiss_Cities'] = df_german.apply(lambda row: find_swiss_cities_in_text(row['Content'], row['Header'], df_cities_german), axis=1)

# %%
switzerland_added = False  # Flag to track if 'Switzerland' is ever added

for idx, row in df_german.iterrows():
    if row['Mentioned_Swiss_Cities'] and "Schweiz" not in row['Mentioned_Countries']:
        df_german.at[idx, 'Mentioned_Countries'] = row['Mentioned_Countries'].union({"Schweiz"})
        print(f"Row {idx} updated: {row}")
        switzerland_added = True

# Check if 'Switzerland' was added in any of the rows
if not switzerland_added:
    print("No updates made. 'Schweiz' was already included in all relevant rows.")
# Out:
# Row 7 updated: Title                               museum begeht tabubruch  und hat erfolg
# Header                                                                baden
# Content                   an der diesjahrigen 20th century art evening a...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 7, dtype: object
# Row 14 updated: Title                     constantin plagen schuldgefuhle, er zeigt sich...
# Header                                                         spitalbesuch
# Content                   ende oktober machten die news die runde, dass ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {sitten }
# Name: 14, dtype: object
# Row 17 updated: Title                     fluchtiger morder erhebt schwere vorwurfe in a...
# Header                                                          deutschland
# Content                   mehrere medien in deutschland haben einen brie...
# Mentioned_Countries                                  {Schweiz, Deutschland}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 17, dtype: object
# Row 23 updated: Title                      pinkfarbenes gewasser auf hawaii gibt ratsel auf
# Header                                 kealia pond national wildlife refuge
# Content                   auf der hawaiianischen insel maui sorgt ein pi...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 23, dtype: object
# Row 24 updated: Title                     zwei tote nach auseinandersetzung  mann noch f...
# Header                                                           ittigen be
# Content                   am fruhen freitagmorgen ist es in ittigen be z...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                     {bern , ittigen}
# Name: 24, dtype: object
# Row 26 updated: Title                     ceo abgesetzt  jetzt sollen die lohne der arzt...
# Header                                                  kantonsspital aarau
# Content                   das kantonsspital aarau (ksa) durchlebt in den...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {aarau }
# Name: 26, dtype: object
# Row 31 updated: Title                     absolutes no-go, was an der herbstmesse passie...
# Header                                                           liestal bl
# Content                   am vergangenen freitag wurde ein 17-jahriger b...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                   {liestal , basel }
# Name: 31, dtype: object
# Row 43 updated: Title                     2 schweizer (20 und 18) erneut in haft  totung...
# Header                                                  balkonsturz in biel
# Content                   ende september ist eine frau an der aegertenst...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {bern }
# Name: 43, dtype: object
# Row 52 updated: Title                     tierqualer haben auch in zug ein schaf geschac...
# Header                                                           stadt zug
# Content                   ein schaf ist am freitag, 20. oktober, in der ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                {zug , schwyz , wald}
# Name: 52, dtype: object
# Row 53 updated: Title                     kopfschuss im klassenzimmer  polizei gibt neue...
# Header                                                           offenburg
# Content                   nach den todlichen schussen eines 15-jahrigen ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 53, dtype: object
# Row 54 updated: Title                     postautochauffeure queren gleise trotz herunte...
# Header                                                         muhlehorn gl
# Content                   auf der social-media-plattform tiktok kursiert...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                       {zug , glarus}
# Name: 54, dtype: object
# Row 57 updated: Title                     bei dieser initiative hast du drei wahlmoglich...
# Header                                                klimafonds st. gallen
# Content                   bei der vorlage zum klimafonds geht es um die ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 57, dtype: object
# Row 119 updated: Title                     das schonste, was mir gott gegeben hat  dwamen...
# Header                                                         social media
# Content                   raphael dwamena war in absoluter top-form, als...
# Mentioned_Countries                                     {Schweiz, Albanien}
# Mentioned_Swiss_Cities                  {st. gallen , winterthur , zurich }
# Name: 119, dtype: object
# Row 127 updated: Title                          mann verletzt ehefrau bei auseinandersetzung
# Header                                                     siegershausen tg
# Content                   eine frau wurde am samstagabend in siegershaus...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {kreuzlingen}
# Name: 127, dtype: object
# Row 128 updated: Title                     so erlebten die mitspieler den tod von raphael...
# Header                                                     emotionale worte
# Content                   ex-fcz-star raphael dwamena starb am samstag i...
# Mentioned_Countries                                        {Schweiz, Ghana}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 128, dtype: object
# Row 130 updated: Title                     gc fegt aufsteiger ouchy dank mitreissendem au...
# Header                                                         super league
# Content                   vor der partie zwischen gc und ouchy sprach br...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                             {st. gallen , lausanne }
# Name: 130, dtype: object
# Row 133 updated: Title                               vermisse dich, du bist der beste bruder
# Header                                                     todlicher unfall
# Content                   bei einem unfall in unterrindal sg kam am sams...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 133, dtype: object
# Row 134 updated: Title                     autofahrer kollidiert beim uberholen mit toffl...
# Header                                                       unterrindal sg
# Content                   wie die kantonspolizei st. gallen mitteilt, ka...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 134, dtype: object
# Row 141 updated: Title                                  plotzlich stand die achterbahn still
# Header                                                                basel
# Content                   am samstagnachmittag kam es an der herbstmesse...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 141, dtype: object
# Row 142 updated: Title                                           zolli-fans trauern um alima
# Header                                                                basel
# Content                   leer stehendes gehege bei den geparden, so ver...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 142, dtype: object
# Row 146 updated: Title                     riesenschnecken boomen als haustiere  jetzt wa...
# Header                                               bis 20 zentimeter lang
# Content                   bis zu 20 zentimeter lange afrikanische riesen...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {lausanne }
# Name: 146, dtype: object
# Row 150 updated: Title                      darum sind velohelme auf spielplatzen gefahrlich
# Header                                                                 chur
# Content                   das tragen eines helms kann zu gefahrlichen un...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {chur }
# Name: 150, dtype: object
# Row 162 updated: Title                       15-jahriger klaut papis cabrio und schrottet es
# Header                                                            jenins gr
# Content                   ein 15-jahriger klaute in der nacht auf sonnta...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {chur }
# Name: 162, dtype: object
# Row 163 updated: Title                     bei der tankstelle eskalierte der streit  20-j...
# Header                                               kriminalgericht luzern
# Content                   ein 20-jahriger kosovare starb im september 20...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {luzern }
# Name: 163, dtype: object
# Row 166 updated: Title                     soziale hierarchie  darum unterbrechen manner ...
# Header                                                      gesprachskultur
# Content                   ob beim gesprach am esstisch, in der hitzigen ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                 {lausanne , zurich }
# Name: 166, dtype: object
# Row 175 updated: Title                     hatte ein defibrillator den tod von dwamena (2...
# Header                                                  liess ihn entfernen
# Content                   ex-fcz-star raphael dwamena starb am samstag i...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                            {lugano , bern , zurich }
# Name: 175, dtype: object
# Row 177 updated: Title                     bund will einkaufstouristen bremsen  doch es g...
# Header                                                         steuergrenze
# Content                   was die einen freut, ist den anderen seit jahr...
# Mentioned_Countries                      {Schweiz, Österreich, Deutschland}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 177, dtype: object
# Row 179 updated: Title                     mann stirbt nach streit  beteiligten drohen ha...
# Header                                              kreisgericht st. gallen
# Content                   ende august 2021 ereignete sich an der st. gal...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 179, dtype: object
# Row 182 updated: Title                            mann mit krucke geschlagen  zeugen gesucht
# Header                                                                 thun
# Content                   die kantonspolizei bern erhielt am sonntag, 13...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                       {thun , bern }
# Name: 182, dtype: object
# Row 189 updated: Title                     wieder gescheitert  die chronologie der matter...
# Header                                                       erneute absage
# Content                   die rennen unterhalb des matterhorns stehen un...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 189, dtype: object
# Row 190 updated: Title                     panik im bus  junger mann schlagt mit nothamme...
# Header                                                           winterthur
# Content                   klirrende scheiben und fluchtende passagiere: ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                               {winterthur , zurich }
# Name: 190, dtype: object
# Row 191 updated: Title                     winterthur will ganzen quartieren bis 2033 gas...
# Header                                                     klimaneutralitat
# Content                   ihre liegenschaft liegt in einem gebiet, in de...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {winterthur }
# Name: 191, dtype: object
# Row 199 updated: Title                     beissender geruch im bahnhof aarau  madchen br...
# Header                                                                aarau
# Content                   wie eine leserin berichtet, fingen am dienstag...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {aarau }
# Name: 199, dtype: object
# Row 204 updated: Title                     ich habe jetzt mittagspause  mitarbeiter lehnt...
# Header                                                                basel
# Content                   als der lift am samstagmittag den vierten stoc...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 204, dtype: object
# Row 205 updated: Title                       und plotzlich gingen in sissach die lichter aus
# Header                                                     basel-landschaft
# Content                   draussen war es bereits dunkel, als in sissach...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 205, dtype: object
# Row 206 updated: Title                     nur novartis-personal konnte diesen dinosaurie...
# Header                                                                basel
# Content                   das naturhistorische museum basel bekommt eine...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 206, dtype: object
# Row 208 updated: Title                     beim jumbo regnet es in die filiale  besucher ...
# Header                                                      allmendingen be
# Content                   eine unverhoffte abkuhlung gabs in der jumbo-f...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {bern }
# Name: 208, dtype: object
# Row 228 updated: Title                     mann sturzt boschung hinunter und wird aus fah...
# Header                                                          frutigen be
# Content                   am dienstagmorgen, um kurz vor 7.30 uhr, ging ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {bern }
# Name: 228, dtype: object
# Row 239 updated: Title                     landwirt filmt wolf in rumlang: kanton warnt t...
# Header                                                          rumlang zh
# Content                   in rumlang zh wurde ein wolf gesichtet: eine l...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 239, dtype: object
# Row 248 updated: Title                              brand in einem wagen der rhatischen bahn
# Header                                                           pontresina
# Content                   am montagmittag brach ein feuer in einem wagen...
# Mentioned_Countries                                      {Schweiz, Italien}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 248, dtype: object
# Row 257 updated: Title                                        er hatte jemanden toten konnen
# Header                                                      spreitenbach ag
# Content                   mehrere autos stehen an der willestrasse in sp...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                       {spreitenbach}
# Name: 257, dtype: object
# Row 258 updated: Title                     der stadtrat ist hochstpersonlich zu mir gekom...
# Header                                                     drama um platane
# Content                   die marktbetreiberin ursula buhler kampft seit...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 258, dtype: object
# Row 265 updated: Title                     verkehrsdienstler angefahren  28-jahriger blei...
# Header                                                 waltensburg/vuorz gr
# Content                   der 28-jahrige verkehrsdienstspezialist regelt...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {chur }
# Name: 265, dtype: object
# Row 277 updated: Title                     baut ihm eine statue  so reagieren union-fans ...
# Header                                                           bundesliga
# Content                   was der mann geleistet hat, ist wirklich ganz ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 277, dtype: object
# Row 285 updated: Title                             das sind die coolsten reiseziele fur 2024
# Header                                                               top 30
# Content                   wenn du im winter schon von palmen, sonne und ...
# Mentioned_Countries            {Madagaskar, Schweiz, Sierra Leone, Italien}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 285, dtype: object
# Row 292 updated: Title                     israel fuhrt krieg gegen die hamas  aber wie e...
# Header                                                         funfte woche
# Content                   wie ist der stand der bodenoffensive? israel w...
# Mentioned_Countries                  {Türkei, Schweiz, Israel, Katar, Iran}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 292, dtype: object
# Row 295 updated: Title                     diese birnen solltest du nicht in deiner obsts...
# Header                                                              ruckruf
# Content                   die in frauenfeld ansassige importfirma giovan...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {frauenfeld }
# Name: 295, dtype: object
# Row 296 updated: Title                     darum solltest du dir tagliches duschen abgewo...
# Header                                                        korperhygiene
# Content                   alle tun es. einige finden es lastig und lasse...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 296, dtype: object
# Row 303 updated: Title                     kesb platziert unschuldige jugendliche in gefa...
# Header                                                   umstrittene praxis
# Content                   die kindes- und erwachsenenschutzbehorde (kesb...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                               {basel , bern , thun }
# Name: 303, dtype: object
# Row 316 updated: Title                     sie versuchten, mit wassereimern den brand zu ...
# Header                                                             arbon tg
# Content                   der anwohner r.d. wollte gerade mit seinem hun...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {arbon }
# Name: 316, dtype: object
# Row 323 updated: Title                     himmutruurig  gemeinden platzt wegen sbb-plane...
# Header                                               solothurner wasseramt
# Content                   auf der strecke wanzwilsolothurn verkehren der...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                  {olten , lenzburg }
# Name: 323, dtype: object
# Row 337 updated: Title                     39-jahriger zwang minderjahrige, ihm nacktbild...
# Header                                                     padokriminalitat
# Content                   krasser fall von sextortion im kanton zurich: ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 337, dtype: object
# Row 347 updated: Title                     deutlich mehr abtreibungen: darum brechen frau...
# Header                                                                basel
# Content                   440 schwangerschaftsabbruche wurden 2022 im ka...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 347, dtype: object
# Row 350 updated: Title                                  auch luzern trifft der hackerangriff
# Header                                                   concevis-datenklau
# Content                   der bund hat am dienstag informiert, dass das ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {luzern }
# Name: 350, dtype: object
# Row 358 updated: Title                     jetzt hat nati-trainer yakin auch noch shaqiri...
# Header                                                     11 gegen israel:
# Content                   es waren 45 minuten zum vergessen. bei der nat...
# Mentioned_Countries                               {Schweiz, Kosovo, Israel}
# Mentioned_Swiss_Cities                                    {lugano , basel }
# Name: 358, dtype: object
# Row 365 updated: Title                     in dieser wohnung willst du als katze nicht leben
# Header                                                          kanton bern
# Content                   in dieser wohnung will man als haustier nicht ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {bern }
# Name: 365, dtype: object
# Row 370 updated: Title                     grossrazzia gegen islamisten in sieben bundesl...
# Header                                                          deutschland
# Content                   die polizei hat im zusammenhang mit ermittlung...
# Mentioned_Countries                          {Schweiz, Israel, Deutschland}
# Mentioned_Swiss_Cities                                             {baden }
# Name: 370, dtype: object
# Row 376 updated: Title                       srf und fussball-experte kay voser trennen sich
# Header                                                             ex-profi
# Content                   der ehemalige fussball-profi kay voser (36) ge...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 376, dtype: object
# Row 378 updated: Title                        ticketkontrolle eskaliert  wegen dem chauffeur
# Header                                                          lorrach (d)
# Content                   am mittwochmittag ist in lorrach (d) eine tick...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {freiburg }
# Name: 378, dtype: object
# Row 388 updated: Title                     chaos in der zentralschweiz  storung legte bah...
# Header                                                                   ov
# Content                   reisende in der zentralschweiz brauchten am do...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 388, dtype: object
# Row 392 updated: Title                                                          er ist hier!
# Header                                                             ragaz sg
# Content                   grosse aufregung am mittwochabend im sonst so ...
# Mentioned_Countries                                {Schweiz, Liechtenstein}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 392, dtype: object
# Row 402 updated: Title                     fur die, die tschugger nicht mogen, gibt es no...
# Header                                              streamingstart november
# Content                   tschugger ist die aktuell wohl beliebteste ser...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                               {wald}
# Name: 402, dtype: object
# Row 406 updated: Title                         verkehrsdienstler erliegt seinen verletzungen
# Header                                                 waltensburg/vuorz gr
# Content                   am montagmittag regelte ein 28-jahriger verkeh...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {chur }
# Name: 406, dtype: object
# Row 424 updated: Title                           alle bekamen ein hotelzimmer, nur wir nicht
# Header                                                                basel
# Content                   sturmtief frederico sorgte am donnerstagabend ...
# Mentioned_Countries                                      {Schweiz, Serbien}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 424, dtype: object
# Row 441 updated: Title                     tote identifiziert, tatverdachtiger weiter auf...
# Header                                           gewaltdelikt in ittigen be
# Content                   bei einem streit an der langfeldstrasse in itt...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                     {bern , ittigen}
# Name: 441, dtype: object
# Row 446 updated: Title                     das hochste holz-hochhaus der welt geht in die...
# Header                                                        50 stockwerke
# Content                   es wird das hochste holz-hochhaus der welt: da...
# Mentioned_Countries                                   {Schweiz, Australien}
# Mentioned_Swiss_Cities                                        {winterthur }
# Name: 446, dtype: object
# Row 450 updated: Title                     horror-bilanz, zwist mit team  das lief mit gr...
# Header                                                       nati-trainerin
# Content                   fast auf den tag genau ein jahr nach ihrer ern...
# Mentioned_Countries       {Schweiz, Philippinen, Spanien, Neuseeland, Au...
# Mentioned_Swiss_Cities                                 {freiburg , zurich }
# Name: 450, dtype: object
# Row 460 updated: Title                     crash mit dem kipper  tunnelarbeiter verletzt ...
# Header                                                         poschiavo gr
# Content                   ein 54-jahriger arbeiter transportierte in der...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {lugano }
# Name: 460, dtype: object
# Row 468 updated: Title                     mann (56) schlagt bei verhaftung zu und randal...
# Header                                                           st. gallen
# Content                   die stadtpolizei st. gallen wollte am donnerst...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 468, dtype: object
# Row 469 updated: Title                     grune wollen staumeldungen abschaffen  bundesr...
# Header                                                      strassenverkehr
# Content                   die staumeldungen im radio sind uberflussig ge...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {luzern }
# Name: 469, dtype: object
# Row 474 updated: Title                     wir bekommen die lohne nicht und die chefin si...
# Header                                                         venus beauty
# Content                   die kosmetik-kette venus beauty hat sich durch...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                   {luzern , zurich }
# Name: 474, dtype: object
# Row 483 updated: Title                     der fahrer (32) hatte wohl lieber weniger getr...
# Header                                                        balterswil tg
# Content                   der autofahrer war gemass den erkenntnissen de...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {frauenfeld }
# Name: 483, dtype: object
# Row 491 updated: Title                     lenker missachtet warnsignale  zug erfasst sei...
# Header                                                           frauenfeld
# Content                   bei der kollision zwischen einem auto und eine...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                  {wil , frauenfeld }
# Name: 491, dtype: object
# Row 510 updated: Title                     eisvogel beim bruten gestort  das kommt sie nu...
# Header                                                           reinach bl
# Content                   der ausflug in das naturschutzgebiet reinacher...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {reinach}
# Name: 510, dtype: object
# Row 513 updated: Title                     2 stunden mehrarbeit und 5 ferientage weg  fur...
# Header                                                       sfs automotive
# Content                   in vielen schweizer industriebetrieben lauft e...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 513, dtype: object
# Row 520 updated: Title                     griff pro-hamas-gruppe gezielt einen schweizer...
# Header                                                       telefon-terror
# Content                   ein journalist von nau.ch fuhrte via whatsapp ...
# Mentioned_Countries                                       {Schweiz, Israel}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 520, dtype: object
# Row 521 updated: Title                        familienvater zoltan findet einfach keinen job
# Header                                          trotz hunderten bewerbungen
# Content                   zoltan varga aus riehen (bs) hat im letzten fe...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {riehen}
# Name: 521, dtype: object
# Row 526 updated: Title                         gegenvorschlag zum klimafonds wird angenommen
# Header                                              abstimmungen st. gallen
# Content                   die stimmburgerinnen und stimmburger des kanto...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                  {wil , st. gallen }
# Name: 526, dtype: object
# Row 527 updated: Title                         gegenvorschlag zum klimafonds wird angenommen
# Header                                              abstimmungen st. gallen
# Content                   die stimmburgerinnen und stimmburger des kanto...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                  {wil , st. gallen }
# Name: 527, dtype: object
# Row 535 updated: Title                            er wollte sich seiner verhaftung entziehen
# Header                                                        eschenbach sg
# Content                   am sonntag, kurz vor 14 uhr, habe ein 34-jahri...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                  {ruti, st. gallen }
# Name: 535, dtype: object
# Row 548 updated: Title                               killer konnte aus psychiatrie entkommen
# Header                                                          lorrach (d)
# Content                   nach mehrtagiger fahndung konnte ein fluchtige...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {freiburg }
# Name: 548, dtype: object
# Row 550 updated: Title                     unglaublich: zwei 15-jahrige gewinnen preis fu...
# Header                                                       zuger filmtage
# Content                   die freunde dylan und rico (beide 15) haben im...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {luzern }
# Name: 550, dtype: object
# Row 566 updated: Title                        passant entdeckt schwerverletzten (26) im wald
# Header                                                       sternenberg zh
# Content                   am samstagabend, kurz vor 21.30 uhr, sah ein a...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                      {wald, zurich }
# Name: 566, dtype: object
# Row 576 updated: Title                     tessiner club rockt die liga  ausserst kuriose...
# Header                                                      national league
# Content                   die meisterschaft in der national league marsc...
# Mentioned_Countries                                     {Schweiz, Schweden}
# Mentioned_Swiss_Cities                             {lugano , bern , kloten}
# Name: 576, dtype: object
# Row 581 updated: Title                         es klang so, als ob es bald explodieren wurde
# Header                                                               basel
# Content                   die kehrichtverbrennungsanlage in basel macht ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 581, dtype: object
# Row 592 updated: Title                     erkaltet? diese fehler solltest du jetzt verme...
# Header                                                           gesundheit
# Content                   kratzender hals, laufende nase und schmerzende...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 592, dtype: object
# Row 595 updated: Title                     fans verklagen formel-1-rennen in las vegas au...
# Header                                                   wilder justizkrimi
# Content                   nach dem glitzercomeback in las vegas droht de...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 595, dtype: object
# Row 597 updated: Title                                       riesenaufgebot wegen amok-alarm
# Header                                                            hallau sh
# Content                   kurz nach 13 uhr am montagnachmittag ging bei ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                      {schaffhausen }
# Name: 597, dtype: object
# Row 602 updated: Title                     sein rundgang mit silikon und kleber kommt ihn...
# Header                                                    kanton st. gallen
# Content                   anfang oktober 2021 betrat ein heute 29-jahrig...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 602, dtype: object
# Row 603 updated: Title                     initiativen fordern 67 fussballfelder furs kli...
# Header                                                    klima basel-stadt
# Content                   am sonntag stimmt der kanton basel-stadt uber ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 603, dtype: object
# Row 609 updated: Title                     wie dieser transporter auf die geleise kam, is...
# Header                                                         montbovon fr
# Content                   zum gluck wurde niemand verletzt: ein news-sco...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {freiburg }
# Name: 609, dtype: object
# Row 626 updated: Title                     die couch hat sie mit einem klettverschluss ge...
# Header                                                           st. gallen
# Content                   am samstagnachmittag gegen 14 uhr hat die stad...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 626, dtype: object
# Row 664 updated: Title                     rentner lost ratsel um gigantischen fledermaus...
# Header                                                   rentner als helfer
# Content                   die breitflugelfledermaus (eptesicus serotinus...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {lausanne }
# Name: 664, dtype: object
# Row 670 updated: Title                                     das sieht aus wie ein ego-shooter
# Header                                                          wolhusen lu
# Content                   das plakat der luzerner polizei ist in wolhuse...
# Mentioned_Countries                                      {Ukraine, Schweiz}
# Mentioned_Swiss_Cities                                            {luzern }
# Name: 670, dtype: object
# Row 675 updated: Title                     junge wahlten milei: sie dachten, schlimmer we...
# Header                                                         argentinien
# Content                   der 53-jahrige rechtpopulist javier milei, der...
# Mentioned_Countries                                  {Schweiz, Argentinien}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 675, dtype: object
# Row 688 updated: Title                     deshalb sollst du einem pistenfahrzeug nie zu ...
# Header                                                             davos gr
# Content                   die skisaison hat an einigen orten bereits wie...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {davos}
# Name: 688, dtype: object
# Row 702 updated: Title                     mit sand uberschutten  kanton will radioaktive...
# Header                                               altlasten im zurichsee
# Content                   rund um die ehemalige chemiefabrik in uetikon ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 702, dtype: object
# Row 711 updated: Title                     baraushilfe (51) vergewaltigte minderjahrige i...
# Header                                                        landesverweis
# Content                   am mittwoch trat der beschuldigte, ein 51-jahr...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 711, dtype: object
# Row 723 updated: Title                     das sind die grossten sorgen der schweizerinne...
# Header                                                              ranking
# Content                   auch dieses jahr hat das forschungsinstitut gf...
# Mentioned_Countries                                      {Ukraine, Schweiz}
# Mentioned_Swiss_Cities                                              {bern }
# Name: 723, dtype: object
# Row 727 updated: Title                     ex-svp-bundesratskandidat hans-ueli vogt wird ...
# Header                                                                  srf
# Content                   es ist eine personalie, die aufhorchen lasst. ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 727, dtype: object
# Row 729 updated: Title                           mini-fahrerin (52) kracht in mehrere mauern
# Header                                                            surava gr
# Content                   eine 52-jahrige autofahrerin fuhr am mittwochm...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                              {chur }
# Name: 729, dtype: object
# Row 731 updated: Title                     nach dem ausgang vergewaltigt  tater zu mild b...
# Header                                                 urteil bundesgericht
# Content                   eine frau wurde im februar 2020 nach einer par...
# Mentioned_Countries                                     {Schweiz, Portugal}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 731, dtype: object
# Row 737 updated: Title                     nach sechs todesfallen  elefantenherde im zoo ...
# Header                                                 elefant kehrt zuruck
# Content                   panang ist zuruck  die 34-jahrige elefantenkuh...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 737, dtype: object
# Row 742 updated: Title                     die tuning-papste von abt motzen audis auf 100...
# Header                                                       abt sportsline
# Content                   seit mehr als 125 jahren gibt es die firma abt...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {bulle }
# Name: 742, dtype: object
# Row 745 updated: Title                     darum ist es genau jetzt auf fussgangerstreife...
# Header                                                           winterzeit
# Content                   gegen ende des jahres wird es fruher dunkel, u...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                           {st. gallen , frauenfeld }
# Name: 745, dtype: object
# Row 749 updated: Title                     archaologin gelingt es, dieses gekritzel zu in...
# Header                                                               basel
# Content                   was hat es mit den linien in der la roche-cota...
# Mentioned_Countries                         {Schweiz, Frankreich, Dänemark}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 749, dtype: object
# Row 750 updated: Title                     karte eingezogen: warnung vor manipulierten bi...
# Header                                                                basel
# Content                   unbekannte tater haben in basel mindestens ein...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                   {liestal , basel }
# Name: 750, dtype: object
# Row 753 updated: Title                             so beschlagt deine brille im winter nicht
# Header                                                              5 tipps
# Content                   noch vor zwei jahren war der winter gepragt vo...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                          {schlieren}
# Name: 753, dtype: object
# Row 756 updated: Title                                       der vorfall war brandgefahrlich
# Header                                                    bremsen versagten
# Content                   in der nahe von domodossola ware es am mittwoc...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 756, dtype: object
# Row 777 updated: Title                     hsg-professor verurteilt: studienergebnisse si...
# Header                                                           st. gallen
# Content                   wolfgang stolzle ist professor an der universi...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 777, dtype: object
# Row 780 updated: Title                     lehrer schickt schuler in die sek b  dann klag...
# Header                                                        kanton zurich
# Content                   wir erwarten von ihnen eine zuteilung in die s...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 780, dtype: object
# Row 781 updated: Title                                         lass dich von der wut tragen!
# Header                                                   kinostart november
# Content                   heute erscheint feminism wtf in den kinos. nac...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 781, dtype: object
# Row 791 updated: Title                       vermeintlicher geiselnehmer wird freigesprochen
# Header                                                   obergericht zurich
# Content                   der mann befindet sich seit august 2019 im gef...
# Mentioned_Countries       {Deutschland, Schweiz, Sudan, Eritrea, Libyen,...
# Mentioned_Swiss_Cities                                   {bulach , zurich }
# Name: 791, dtype: object
# Row 795 updated: Title                     swisspass-inhaber wird jeden monat erneut fur ...
# Header                                                                panne
# Content                   als ein swisspass-inhaber aus dem kanton solot...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                         {solothurn }
# Name: 795, dtype: object
# Row 798 updated: Title                                 islamgegner geert wilders triumphiert
# Header                                                          niederlande
# Content                   die niederlande stehen nach dem triumphalen wa...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                               {zug }
# Name: 798, dtype: object
# Row 818 updated: Title                     uberlebenswichtig: zieh deinem kind vor der fa...
# Header                                              stadtpolizei st. gallen
# Content                   dieser fehler konnte fur dein kind verheerende...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 818, dtype: object
# Row 826 updated: Title                                                 was soll der quatsch?
# Header                                                             arbon tg
# Content                   in einer facebook-gruppe aus arbon spekulieren...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {arbon }
# Name: 826, dtype: object
# Row 828 updated: Title                     anwohnerin: die dealer garantieren fur unsere ...
# Header                                                                basel
# Content                   als es am donnerstag eindunkelt, versammeln si...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                             {basel }
# Name: 828, dtype: object
# Row 838 updated: Title                     das bedeutet der vormarsch von rechtspopuliste...
# Header                                                           die folgen
# Content                   rechtspopulisten sind in vielen europaischen l...
# Mentioned_Countries                     {Schweiz, Türkei, Dänemark, Ungarn}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 838, dtype: object
# Row 850 updated: Title                      presserat heisst beschwerde gegen 20 minuten gut
# Header                                                     in eigener sache
# Content                   am 10. juni 2022 publizierte 20 minuten einen ...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                         {neuenburg }
# Name: 850, dtype: object
# Row 851 updated: Title                     nach todlichem streit  tatverdachtiger in unga...
# Header                                                           ittigen be
# Content                   im zuge einer auseinandersetzung, die sich am ...
# Mentioned_Countries                                       {Schweiz, Ungarn}
# Mentioned_Swiss_Cities                                     {bern , ittigen}
# Name: 851, dtype: object
# Row 855 updated: Title                     15 jahre spater meldete sich der tater auf fac...
# Header                                               kriminalgericht luzern
# Content                   ein heute 43-jahriger mann musste sich vor dem...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                       {basel , st. gallen , luzern }
# Name: 855, dtype: object
# Row 863 updated: Title                     massenentlassungen in spitalern: jetzt spricht...
# Header                                              nach massenentlassungen
# Content                   lange war es ruhig um den verwaltungsrat der s...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 863, dtype: object
# Row 875 updated: Title                         neu installierte kameras sorgen fur aufregung
# Header                                                         rorschach sg
# Content                   weiss jemand, warum jetzt uberall kameras an l...
# Mentioned_Countries                                               {Schweiz}
# Mentioned_Swiss_Cities                                        {st. gallen }
# Name: 875, dtype: object
# Row 887 updated: Title                     rechtspopulisten sind in europa auf dem vormar...
# Header                                                        ursachensuche
# Content                   geert wilders ist der schlimmste albtraum der ...
# Mentioned_Countries                                   {Schweiz, Frankreich}
# Mentioned_Swiss_Cities                                            {zurich }
# Name: 887, dtype: object

# %%
city_counts = df_german.explode('Mentioned_Swiss_Cities')['Mentioned_Swiss_Cities'].value_counts()
df_city_counts = pd.DataFrame({'City': city_counts.index, 'Count': city_counts.values})
df_city_counts.sort_values(by='Count', ascending=False, inplace=True)

# %%
df_city_count_data = df_city_counts.merge(df_cities_german, left_on='City', right_on='Name', how='left')
df_city_count_data = df_city_count_data[['City', 'Count', 'Coordinates', 'Longitude', 'Latitude']]

# %% [markdown]
# ### Exports

# %%
csv_file_path = 'inputdata/df_cities_german_with_coordinates.csv'
df_cities_german.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'inputdata/df_countries_german_with_capital_and_coordinates.csv'
df_countries_german.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_german_with_mentions.csv'
df_german.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_city_count_data.csv'
df_city_count_data.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_country_count_data.csv'
df_country_count_data.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_translated_country_count_data.csv'
df_final_country_count_data.to_csv(csv_file_path, index=False)

# %% [markdown]
# ### Debugs

# %%
def find_swiss_cities_in_text_debug(content, header, df_cities_german):
    combined_text = (str(content) + " " + str(header)).lower()
    mentioned_swiss_cities = set()

    print("Combined Text:", combined_text)  # Debug print

    for city in df_cities_german['Name']:
        city_lower = city.lower()
        print(f"Checking for city: {city_lower}")  # Debug print
        if city_lower in combined_text:
            mentioned_swiss_cities.add(city)

    return mentioned_swiss_cities

# Test the function with the first row's content and header
mentioned_cities_debug = find_swiss_cities_in_text_debug(first_row_content, first_row_header, df_cities_german)
print("Mentioned Swiss cities in the first row (Debug):", mentioned_cities_debug)

# %%
import unicodedata

def normalize_text(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii').lower()

def find_swiss_cities_in_text_debug(content, header, df_cities_german):
    combined_text = normalize_text(str(content) + " " + str(header))
    mentioned_swiss_cities = set()

    print("Normalized Combined Text:", combined_text)  # Debug print

    for city in df_cities_german['Name']:
        normalized_city = normalize_text(city)
        print(f"Checking for city: {normalized_city}")  # Debug print
        if normalized_city in combined_text:
            mentioned_swiss_cities.add(city)

    return mentioned_swiss_cities

# Test the function with the first row's content and header
mentioned_cities_debug = find_swiss_cities_in_text_debug(first_row_content, first_row_header, df_cities_german)
print("Mentioned Swiss cities in the first row (Debug):", mentioned_cities_debug)

# %%
def find_swiss_cities_in_text(content, header, df_cities_german):
    combined_text = normalize_text(str(content) + " " + str(header))
    print("Normalized Combined Text:", combined_text)  # Debug print

    mentioned_swiss_cities = set()

    normalized_swiss_city_names = set(df_cities_german['Name'].apply(normalize_text))
    print("Normalized Swiss City Names:", normalized_swiss_city_names)  # Debug print

    for city in normalized_swiss_city_names:
        print(f"Checking for city: {city}")  # Debug print
        if city in combined_text:
            mentioned_swiss_cities.add(city)

    return mentioned_swiss_cities

# Testing the function with a single row (e.g., first row) from df_german
test_row = df_german.iloc[0]
test_mentioned_cities = find_swiss_cities_in_text(test_row['Content'], test_row['Header'], df_cities_german)
print("Mentioned Swiss cities in test row:", test_mentioned_cities)

# %%
test_row = df_german.iloc[0]
