# %% [markdown]
# # Location Analysis French

# %% [markdown]
# ### Setup

# %% [markdown]
# **Important imports**

# %%
import pandas as pd
import spacy
import requests
import time
import re
import unicodedata

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
df_french = pd.read_csv('../../scraping/data/extractor_all_articles_20minutes.csv')
df_cities_french = pd.read_csv('inputdata/listedesvilles_suisse.csv')
df_countries_french = pd.read_csv('inputdata/country_capital_french.csv')
data_german = pd.read_csv('inputdata/df_countries_german_with_capital_and_coordinates.csv')
df_cantons_french = pd.read_csv('inputdata/cantons.csv')

# %%
french_iso_3166 = pd.read_csv('inputdata/french-iso-3166.csv')
english_iso_3166 = pd.read_csv('inputdata/english-iso-3166.csv', usecols=['alpha-2', 'name', 'alpha-3'])
english_iso_3166.columns = ['Name', 'ISO2', 'ISO3']

# %%
df_cantons_french
# Out:
#                            Canton
# 0                         zurich
# 1                           berne
# 2                        lucerne
# 3                             uri
# 4                         schwytz
# 5                          obwald
# 6                         nidwald
# 7                          glaris
# 8                           zoug
# 9                        fribourg
# 10                        soleure
# 11                     bale-ville
# 12                  bale-campagne
# 13                   schaffhouse
# 14  appenzell rhodes-exterieures
# 15   appenzell rhodes-interieures
# 16                     saint-gall
# 17                        grisons
# 18                        argovie
# 19                      thurgovie
# 20                         tessin
# 21                           vaud
# 22                         valais
# 23                      neuchatel
# 24                         geneve
# 25                           jura

# %% [markdown]
# **Loading dataframes and cleaning them**

# %%
def normalize_text(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii').lower()

# %%
def apply_normalize_text_if_str(x):
    return normalize_text(x) if isinstance(x, str) else x

# %%
def lowercase_columns(df, columns):
    for column in columns:
        df[column] = df[column].str.lower()

# %%
columns_to_normalize = ['Content', 'Title', 'Header']
df_french[columns_to_normalize] = df_french[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
df_cantons_french['Canton'] = df_cantons_french['Canton'].apply(lambda x: normalize_text(x) if isinstance(x, str) else x)
df_cantons_french = df_cantons_french[['Canton']]

# %%
columns_to_normalize = ['Name', 'Capital']
df_countries_french[columns_to_normalize] = df_countries_french[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
columns_to_normalize = ['Name']
french_iso_3166[columns_to_normalize] = french_iso_3166[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
columns_to_normalize = ['Country', 'Capital']
df_countries_french[columns_to_normalize] = df_countries_french[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
df_cities_french['Ville'] = df_cities_french['Ville'].apply(lambda x: normalize_text(x) if isinstance(x, str) else x)
df_cities_french = df_cities_french[['Ville', 'Coordinates', 'Latitude', 'Longitude']]

# %%
df_countries_french = df_countries_french.merge(french_iso_3166, left_on='Country', right_on='Name', how='left')
df_countries_french = df_countries_french[['Country', 'Capital', 'ISO2', 'ISO3']]

# %%
columns_to_normalize = ['Title', 'Header', 'Content']
df_french[columns_to_normalize] = df_french[columns_to_normalize].applymap(apply_normalize_text_if_str)

# %%
df_french
# Out:
#                                                   Title             Header  \
# 0     dix-huit prevenus condamnes dans laffaire du c...  justice francaise
# 1     elle sengage sur lautoroute avec le reservoir ...            argovie
# 2     au portugal, la course au poste de premier min...          politique
# 3     le vote de journalistes, dont celui de la rts,...        ballon d'or
# 4     la premiere ministre refuse de hausser le sala...        bangladesh
# ...                                                 ...                ...
# 1055  une tristesse indescriptible aux obseques de t...             france
# 1056  une voiture en feu a provoque la fermeture du ...                uri
# 1057  la commune voisine de paleo veut negocier des ...        trelex (vd)
# 1058  les patins crissent a nouveau au parc des bast...    ville de geneve
# 1059       vous ne detesterez plus le chou de bruxelles      legume dhiver
#
#                                                 Content  \
# 0     un dessein purement lucratif. dix-huit des 19 ...
# 1     malgre un signal lumineux indiquant que le sto...
# 2     les principaux partis ont commence vendredi a ...
# 3     dans le debat haaland-messi pour le ballon d'o...
# 4     la premiere ministre du bangladesh, sheikh has...
# ...                                                 ...
# 1055  nous taimons et nous ne toublierons jamais. pr...
# 1056  le tunnel routier du gothard est reste ferme d...
# 1057  ces derniers jours, le conseil communal de tre...
# 1058  les mesures covid en 2021 puis les restriction...
# 1059  meme si certains redoutent de le voir dans leu...
#
#                                     Mentioned_Countries
# 0                                 {royaume-uni, france}
# 1                                              {suisse}
# 2                                            {portugal}
# 3                     {danemark, suisse, liban, panama}
# 4                                          {bangladesh}
# ...                                                 ...
# 1055                                           {france}
# 1056                                           {suisse}
# 1057                                                 {}
# 1058                                                 {}
# 1059  {suisse, pays-bas, royaume-uni, belgique, france}
#
# [1060 rows x 4 columns]

# %% [markdown]
# ### Add Coordinates Functionality

# %%
geocode_api_key = '1983e85e9a97673a09ed6d19417dda0f'

# %%
def geocode_location_positionstack(location_name, api_key):
    base_url = "http://api.positionstack.com/v1/forward"
    params = {
        'access_key': api_key,
        'query': location_name,
        'limit': 1,
    }
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data['data']:
            latitude = data['data'][0]['latitude']
            longitude = data['data'][0]['longitude']
            return latitude, longitude
        else:
            return None, None
    else:
        print(f"Error: {response.status_code}")
        return None, None

# %%
def add_coordinates(row, column_name, api_key):
    location_name = row[column_name]
    lat, lng = geocode_location_positionstack(location_name, api_key)
    return pd.Series({'Coordinates': (lat, lng), 'Latitude': lat, 'Longitude': lng})

# %% [markdown]
# **Add coordinates to cities in Switzerland**

# %%
temp_df = df_cities_french[pd.isna(df_cities_french['Coordinates'])].copy()
temp_df[['Coordinates', 'Latitude', 'Longitude']] = temp_df.apply(lambda row: add_coordinates(row, 'Ville', geocode_api_key), axis=1)

# %%
for idx, row in temp_df.iterrows():
    df_cities_french.loc[idx, ['Coordinates', 'Latitude', 'Longitude']] = row[['Coordinates', 'Latitude', 'Longitude']]

# %% [markdown]
# **Add coordinates to capital cities worldwide**

# %%
df_countries_french[['Coordinates', 'Latitude', 'Longitude']] = df_countries_french.apply(lambda row: add_coordinates(row, 'Capital', geocode_api_key), axis=1)
# Out:
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400
# Error: 400

# %%
for idx, row in df_countries_french.iterrows():
    if pd.isna(row['Latitude']):
        try:
            lat, lng = geocode_location_positionstack(row['Capital'], geocode_api_key)
            print(f"Fetching for {row['Capital']}: Lat {lat}, Lng {lng}")  # Debug print

            if lat is not None and lng is not None:
                df_countries_french.at[idx, 'Coordinates'] = (lat, lng)
                df_countries_french.at[idx, 'Latitude'] = lat
                df_countries_french.at[idx, 'Longitude'] = lng
        except Exception as e:
            print(f"Error fetching coordinates for {row['Capital']}: {e}")
# Out:
# Fetching for canberra: Lat -35.470057, Lng 148.954507
# Fetching for caracas: Lat 10.505146, Lng -66.917878
# Fetching for castries: Lat 14.008326, Lng -60.989868
# Fetching for cetinje (presidentielle): Lat 42.392165, Lng 18.923124
# Fetching for podgorica (administrative): Lat 42.44111, Lng 19.26361
# Fetching for chisinau: Lat 47.020682, Lng 28.854719
# Fetching for colombo (executive et judiciaire): Lat 6.934744, Lng 79.842725
# Fetching for sri jayawardenapura kotte (officielle et legislative): Lat 6.907821, Lng 79.894725
# Fetching for comayaguela (es): Lat 13.6, Lng -87.71667
# Fetching for tegucigalpa: Lat 14.0818, Lng -87.20681
# Fetching for conakry: Lat 9.51356, Lng -13.703869
# Fetching for copenhague: Lat 55.704438, Lng 12.502119
# Fetching for cotonou (de facto): Lat 6.36536, Lng 2.41833
# Fetching for porto-novo (officielle): Lat 6.491262, Lng 2.625751
# Fetching for dakar: Lat 14.713018, Lng -17.454726
# Fetching for damas: Lat 33.5102, Lng 36.29128
# Fetching for dacca: Lat 23.7104, Lng 90.40744
# Fetching for dar es salam (de facto, judiciaire): Lat 9.578749, Lng -13.635246
# Fetching for dodoma (officielle, legislative): Lat -7.29067, Lng 36.34038
# Fetching for dili: Lat 28.665996, Lng 77.115075
# Fetching for djibouti: Lat 11.58901, Lng 43.14503
# Fetching for djouba: Lat 4.85165, Lng 31.58247
# Fetching for doha: Lat 25.251557, Lng 51.564826
# Fetching for la paz (gouvernement et ambassades): Lat None, Lng None

# %% [markdown]
# ### Search Functions

# %% [markdown]
# #### Country Search

# %%
def process_entity(ent, mentioned_countries, country_data_french, swiss_cities_french, swiss_cantons_french):
    if ent.label_ in ['LOC', 'GPE']:
        entity_parts = ent.text.lower().split()

        for part in entity_parts:
            if part in swiss_cities_french['Ville'].str.lower().values or part in swiss_cantons_french['Canton'].str.lower().values:
                mentioned_countries.add("suisse")
                break

        # Check if the entity is a capital, then add corresponding country
        country_from_capital = country_data_french[country_data_french['Capital'].str.lower() == ent.text.lower()]['Country']
        if not country_from_capital.empty:
            mentioned_countries.add(country_from_capital.iloc[0])
            return

        # Check if the entity is a country
        country = country_data_french[country_data_french['Country'].str.lower() == ent.text.lower()]['Country']
        if not country.empty:
            mentioned_countries.add(country.iloc[0])

# %%
def find_countries_in_text(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    # Use SpaCy for processing the content
    doc = nlp(content)
    mentioned_countries = set()

    for ent in doc.ents:
        if ent.label_ in ['LOC', 'GPE']:
            process_entity(ent, mentioned_countries, country_data_french, swiss_cities_french, swiss_cantons_french)

    # Process the header with a keyword-based approach
    header_parts = header.lower().split()
    for part in header_parts:
        if part in swiss_cities_french['Ville'].str.lower().values or part in swiss_cantons_french['Canton'].str.lower().values:
            mentioned_countries.add("suisse")
            continue

        # Check if the part is a capital, then add corresponding country
        country_from_capital = country_data_french[country_data_french['Capital'].str.lower() == part]['Country']
        if not country_from_capital.empty:
            mentioned_countries.add(country_from_capital.iloc[0])
            continue

        # Check if the part is a country
        country = country_data_french[country_data_french['Country'].str.lower() == part]['Country']
        if not country.empty:
            mentioned_countries.add(country.iloc[0])

    return mentioned_countries

# %%
df_french['Mentioned_Countries'] = df_french.apply(lambda row: find_countries_in_text(row['Content'], row['Header'], df_countries_french, df_cities_french, df_cantons_french), axis=1)

# %%
df_country_counts
# Out:
#                 Country  Count
# 0                suisse    398
# 1            etats-unis    130
# 2                france    121
# 3                russie     42
# 4           royaume-uni     37
# ..                  ...    ...
# 95           seychelles      1
# 94            guatemala      1
# 93   guinee equatoriale      1
# 92          afghanistan      1
# 119          montenegro      1
#
# [120 rows x 2 columns]

# %% [markdown]
# #### Count Country Mentions

# %%
country_counts = df_french.explode('Mentioned_Countries')['Mentioned_Countries'].value_counts()
df_country_counts = pd.DataFrame({'Country': country_counts.index, 'Count': country_counts.values})
df_country_counts.sort_values(by='Count', ascending=False, inplace=True)

# %%
df_country_count_data = df_country_counts.merge(df_countries_french, left_on='Country', right_on='Country', how='left')
df_country_count_data = df_country_count_data[['Country', 'Count', 'ISO2', 'ISO3', 'Capital', 'Coordinates', 'Latitude', 'Longitude']]

# %%
df_country_count_data
# Out:
#                 Country  Count ISO2 ISO3                     Capital  \
# 0                suisse    398   CH  CHE            berne (de facto)
# 1            etats-unis    130   US  USA                  washington
# 2                france    121   FR  FRA                       paris
# 3                russie     42   RU  RUS                      moscou
# 4           royaume-uni     37   GB  GBR                     londres
# ..                  ...    ...  ...  ...                         ...
# 126           guatemala      1   GT  GTM                   guatemala
# 127  guinee equatoriale      1   GQ  GNQ                      malabo
# 128         afghanistan      1   AF  AFG                      kaboul
# 129          montenegro      1   ME  MNE    cetinje (presidentielle)
# 130          montenegro      1   ME  MNE  podgorica (administrative)
#
#                 Coordinates   Latitude  Longitude
# 0     (53.156582, 8.385292)  53.156582   8.385292
# 1     (38.82652, -77.01712)  38.826520 -77.017120
# 2     (48.858705, 2.342865)  48.858705   2.342865
# 3    (55.741469, 37.615561)  55.741469  37.615561
# 4    (51.509648, -0.099076)  51.509648  -0.099076
# ..                      ...        ...        ...
# 126   (14.64072, -90.51327)  14.640720 -90.513270
# 127         (3.75, 8.78333)   3.750000   8.783330
# 128    (34.52813, 69.17233)  34.528130  69.172330
# 129            (None, None)        NaN        NaN
# 130            (None, None)        NaN        NaN
#
# [131 rows x 8 columns]

# %% [markdown]
# **Add translation so that we have German and English Names (based on ISO Codes)**

# %%
df_countries_french
# Out:
#                  Country           Capital ISO2 ISO3             Coordinates  \
# 0    emirats arabes unis         abou dabi   AE  ARE  (24.365909, 54.582942)
# 1                nigeria             abuja   NG  NGA    (9.047364, 7.434935)
# 2                  ghana             accra   GH  GHA   (5.545935, -0.210089)
# 3           turkmenistan          achgabat   TM  TKM       (37.95, 58.38333)
# 4               ethiopie       addis-abeba   ET  ETH   (9.018947, 38.746032)
# ..                   ...               ...  ...  ...                     ...
# 209             cameroun           yaounde   CM  CMR     (3.86667, 11.51667)
# 210                nauru  yaren (de facto)   NR  NRU    (-0.55085, 166.9252)
# 211              croatie            zagreb   HR  HRV  (45.806026, 15.976218)
# 212               kosovo          pristina   XK  NaN    (42.67272, 21.16688)
# 213               taiwan            taipei   TW  TWN   (25.04776, 121.53185)
#
#       Latitude   Longitude
# 0    24.365909   54.582942
# 1     9.047364    7.434935
# 2     5.545935   -0.210089
# 3    37.950000   58.383330
# 4     9.018947   38.746032
# ..         ...         ...
# 209   3.866670   11.516670
# 210  -0.550850  166.925200
# 211  45.806026   15.976218
# 212  42.672720   21.166880
# 213  25.047760  121.531850
#
# [214 rows x 7 columns]

# %%
df_final_country_count_data = df_country_count_data.merge(english_iso_3166, on='ISO2', how='left')

# Rename the 'Name' column from english_iso_3166 to 'EnglishName'
df_final_country_count_data.rename(columns={'Name': 'EnglishName'}, inplace=True)
df_final_country_count_data.rename(columns={'Country': 'FrenchName'}, inplace=True)

# %%
desired_columns = [
    'FrenchName', 'Count', 'Coordinates', 'Longitude',
    'Latitude', 'ISO2', 'ISO3_x', 'EnglishName', 'Capital'
]


df_final_country_count_data = df_final_country_count_data[desired_columns]
df_final_country_count_data = df_final_country_count_data.rename(columns= {"ISO3_x": "ISO3"})

# %%
df_final_country_count_data
# Out:
#              FrenchName  Count             Coordinates  Longitude   Latitude  \
# 0                suisse    398   (53.156582, 8.385292)   8.385292  53.156582
# 1            etats-unis    130   (38.82652, -77.01712) -77.017120  38.826520
# 2                france    121   (48.858705, 2.342865)   2.342865  48.858705
# 3                russie     42  (55.741469, 37.615561)  37.615561  55.741469
# 4           royaume-uni     37  (51.509648, -0.099076)  -0.099076  51.509648
# ..                  ...    ...                     ...        ...        ...
# 126           guatemala      1   (14.64072, -90.51327) -90.513270  14.640720
# 127  guinee equatoriale      1         (3.75, 8.78333)   8.783330   3.750000
# 128         afghanistan      1    (34.52813, 69.17233)  69.172330  34.528130
# 129          montenegro      1            (None, None)        NaN        NaN
# 130          montenegro      1            (None, None)        NaN        NaN
#
#     ISO2 ISO3                                        EnglishName  \
# 0     CH  CHE                                        Switzerland
# 1     US  USA                           United States of America
# 2     FR  FRA                                             France
# 3     RU  RUS                                 Russian Federation
# 4     GB  GBR  United Kingdom of Great Britain and Northern I...
# ..   ...  ...                                                ...
# 126   GT  GTM                                          Guatemala
# 127   GQ  GNQ                                  Equatorial Guinea
# 128   AF  AFG                                        Afghanistan
# 129   ME  MNE                                         Montenegro
# 130   ME  MNE                                         Montenegro
#
#                         Capital
# 0              berne (de facto)
# 1                    washington
# 2                         paris
# 3                        moscou
# 4                       londres
# ..                          ...
# 126                   guatemala
# 127                      malabo
# 128                      kaboul
# 129    cetinje (presidentielle)
# 130  podgorica (administrative)
#
# [131 rows x 9 columns]

# %%
df_cities_french
# Out:
#              Ville               Coordinates   Latitude   Longitude
# 0           zurich     (46.201511, 6.143889)  46.201511    6.143889
# 1           geneve     (47.553808, 7.592036)  47.553808    7.592036
# 2             bale      (46.520381, 6.63141)  46.520381    6.631410
# 3         lausanne     (46.946416, 7.396394)  46.946416    7.396394
# 4            berne     (47.499693, 8.728495)  47.499693    8.728495
# ..             ...                       ...        ...         ...
# 165      appenzell       (47.32812, 9.40792)  47.328120    9.407920
# 166     interlaken  (36.955382, -121.745858)  36.955382 -121.745858
# 167   saint-moritz     (46.498322, 9.843629)  46.498322    9.843629
# 168  la neuveville      (47.062931, 7.09602)  47.062931    7.096020
# 169          arosa     (46.785385, 9.678935)  46.785385    9.678935
#
# [170 rows x 4 columns]

# %% [markdown]
# #### City Search

# %%
def find_swiss_cities_in_text(content, header, df_cities_german):
    combined_text = normalize_text(str(content) + " " + str(header)).strip()
    mentioned_swiss_cities = set()

    for city in df_cities_german['Ville']:
        normalized_city = normalize_text(city).strip()
        # Use a regular expression to find whole word matches only
        if re.search(r'\b' + re.escape(normalized_city) + r'\b', combined_text):
            mentioned_swiss_cities.add(city)

    return mentioned_swiss_cities

# %%
df_french['Mentioned_Swiss_Cities'] = df_french.apply(lambda row: find_swiss_cities_in_text(row['Content'], row['Header'], df_cities_french), axis=1)

# %%
switzerland_added = False  # Flag to track if 'Switzerland' is ever added

for idx, row in df_french.iterrows():
    if row['Mentioned_Swiss_Cities'] and "suisse" not in row['Mentioned_Countries']:
        df_french.at[idx, 'Mentioned_Countries'] = row['Mentioned_Countries'].union({"suisse"})
        print(f"Row {idx} updated: {row}")
        switzerland_added = True

# Check if 'Switzerland' was added in any of the rows
if not switzerland_added:
    print("No updates made. 'suisse' was already included in all relevant rows.")
# Out:
# Row 41 updated: Title                     grands bandits pour le parquet, amateurs naifs...
# Header                                             montagnes neuchateloises
# Content                   a-t-elle affaire a une poignee de pieds nickel...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                  {la chaux-de-fonds}
# Name: 41, dtype: object
# Row 49 updated: Title                     le troisieme entrainement a zermatt a nouveau ...
# Header                                                            ski alpin
# Content                   experte a meteo suisse, aude untersee avait vu...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 49, dtype: object
# Row 100 updated: Title                     a carouge, le plr garde son siege, a onex, le ...
# Header                                            elections communales (ge)
# Content                   les electeurs de carouge et donex votaient ce ...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                      {carouge, onex}
# Name: 100, dtype: object
# Row 128 updated: Title                     la deuxieme descente de zermatt-cervinia est a...
# Header                                                            ski alpin
# Content                   la seconde descente hommes de coupe du monde d...
# Mentioned_Countries                    {finlande, suisse, autriche, italie}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 128, dtype: object
# Row 146 updated: Title                     lelimination de petra vlhova fait le bonheur d...
# Header                                                  ski  slalom de levi
# Content                   pas de double cette annee pour petra vlhova a ...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 146, dtype: object
# Row 210 updated: Title                     ne faites pas la sourde oreille quand vous ent...
# Header                                                          a la maison
# Content                   le grincement dune porte ou les pas des voisin...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                              {bulle}
# Name: 210, dtype: object
# Row 217 updated: Title                      onze suissesses et meteo compliquee pour zermatt
# Header                                                            ski alpin
# Content                   elles nont pas toutes un dossard assure pour l...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 217, dtype: object
# Row 234 updated: Title                     tenez-vous eloigne des cours d'eau, ruisseaux ...
# Header                                               alerte aux intemperies
# Content                   les personnes abonnees aux notifications du sy...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {monthey}
# Name: 234, dtype: object
# Row 235 updated: Title                            un forcene a ete interpelle a son domicile
# Header                                                         veyrier (ge)
# Content                   le groupe dintervention de la police, notammen...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 235, dtype: object
# Row 277 updated: Title                       bienne peut se faire de la bile, rappi y croire
# Header                                                               hockey
# Content                   les choses ne semblaient pourtant pas si mal e...
# Mentioned_Countries                                     {allemagne, suisse}
# Mentioned_Swiss_Cities                                    {rapperswil-jona}
# Name: 277, dtype: object
# Row 282 updated: Title                     israel na aucune preuve de vie des otages du h...
# Header                                                        proche-orient
# Content                   la croix-rouge na pas rencontre les personnes ...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 282, dtype: object
# Row 292 updated: Title                     sion sous les etoiles devoile ses premieres stars
# Header                                                             festival
# Content                   lors du bilan de ledition, record, de 2023, mi...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                       {geneve, sion}
# Name: 292, dtype: object
# Row 296 updated: Title                              les inondations se multiplient en suisse
# Header                                                                meteo
# Content                   dans plusieurs regions du pays, la prudence es...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                         {geneve, monthey, pfaffikon}
# Name: 296, dtype: object
# Row 312 updated: Title                          pourquoi les vieux couples font moins lamour
# Header                                                               psycho
# Content                   au debut de votre relation, vous ne pensiez qu...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                               {bale}
# Name: 312, dtype: object
# Row 329 updated: Title                     sept suissesses en quete de la ligue des champ...
# Header                                                             football
# Content                   qui succedera au fc barcelone? les premiers ma...
# Mentioned_Countries       {suisse, italie, france, norvege, republique t...
# Mentioned_Swiss_Cities                                             {zurich}
# Name: 329, dtype: object
# Row 364 updated: Title                     geneve-servette en mauvaise posture en ligue d...
# Header                                                     hockey sur glace
# Content                   laventure europeenne des aigles bat de laile. ...
# Mentioned_Countries                                     {allemagne, suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 364, dtype: object
# Row 376 updated: Title                     laffiche du montreux jazz se la joue ou est ch...
# Header                                                             festival
# Content                   laffiche du montreux jazz festival, dont le cr...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                           {montreux}
# Name: 376, dtype: object
# Row 381 updated: Title                           lincendiaire presume reste sous les verrous
# Header                                                       le lignon (ge)
# Content                   le suspect de lincendie mortel survenu dans la...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                    {geneve, vernier}
# Name: 381, dtype: object
# Row 388 updated: Title                     le canton de vaud veut abattre le male alpha d...
# Header                                                                 loup
# Content                   les questions relatives a la gestion du loup o...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                              {berne}
# Name: 388, dtype: object
# Row 396 updated: Title                     un octogenaire perd la vie, fauche sur un pass...
# Header                                                            orbe (vd)
# Content                   un terrible accident de la circulation a eu li...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {granges}
# Name: 396, dtype: object
# Row 401 updated: Title                       premier entrainement des dames annule a zermatt
# Header                                                            ski alpin
# Content                   le premier entrainement en vue des deux descen...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 401, dtype: object
# Row 430 updated: Title                     internet devient une religion, surtout chez le...
# Header                                                                etude
# Content                   a lheure ou lintelligence artificielle est ame...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {zurich}
# Name: 430, dtype: object
# Row 446 updated: Title                     des cartouches suisses suspectees detre vendue...
# Header                                                           neutralite
# Content                   des documents publies par un journaliste sur u...
# Mentioned_Countries                              {ukraine, suisse, pologne}
# Mentioned_Swiss_Cities                                             {thoune}
# Name: 446, dtype: object
# Row 477 updated: Title                     les autrichiennes dominent le premier entraine...
# Header                                                            ski alpin
# Content                   les skieuses ont enfin pu devaler la piste gra...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 477, dtype: object
# Row 520 updated: Title                     le ls va avoir un nouveau grand frere la semai...
# Header                                                             football
# Content                   apres l'ogc nice, rachete par le groupe petroc...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                           {lausanne}
# Name: 520, dtype: object
# Row 555 updated: Title                     fribourg-gotteron, en mode diesel, renoue avec...
# Header                                                     hockey sur glace
# Content                   fribourg-gotteron a choisi le bon soir pour go...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                    {berne, fribourg}
# Name: 555, dtype: object
# Row 560 updated: Title                          lentrainement de zermatt/cervinia est annule
# Header                                                            ski alpin
# Content                   les specialistes de descente nauront finalemen...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 560, dtype: object
# Row 561 updated: Title                     lincontournable reunion des capitaines a cervinia
# Header                                                            ski alpin
# Content                   une salle pleine, des dizaines de journalistes...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 561, dtype: object
# Row 583 updated: Title                     les equipes suisses simposent pour leur entree...
# Header                                                              curling
# Content                   belle journee pour les curlers et curleuses su...
# Mentioned_Countries                   {danemark, suisse, pays-bas, turquie}
# Mentioned_Swiss_Cities                                      {geneve, aarau}
# Name: 583, dtype: object
# Row 610 updated: Title                                premiere finale pour sinner au masters
# Header                                                               tennis
# Content                   jannik sinner est sur son nuage depuis le coup...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                               {bale}
# Name: 610, dtype: object
# Row 624 updated: Title                     henrik kristoffersen fustige des militants idiots
# Header                                                            ski alpin
# Content                   les polemiques ne sarretent plus depuis le ret...
# Mentioned_Countries                                      {suisse, autriche}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 624, dtype: object
# Row 630 updated: Title                     la balle de mcilroy finit entre les jambes dun...
# Header                                                                 golf
# Content                   alors quil participait a letape de dubai du dp...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {sierre}
# Name: 630, dtype: object
# Row 641 updated: Title                                           gagne tes billets pour jain
# Header                                                             concours
# Content                   apres 4 annees dexplorations musicales loin de...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                     {geneve, thonex}
# Name: 641, dtype: object
# Row 710 updated: Title                     les suissesses poursuivent leur sans-faute aux...
# Header                                                              curling
# Content                   les suissesses sont absolument intouchables au...
# Mentioned_Countries                             {finlande, suisse, norvege}
# Mentioned_Swiss_Cities                                              {aarau}
# Name: 710, dtype: object
# Row 735 updated: Title                     gerd zenhausern nomme directeur sportif de got...
# Header                                                     hockey sur glace
# Content                   le suspense concernant le poste de directeur s...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                           {fribourg}
# Name: 735, dtype: object
# Row 814 updated: Title                     une plainte pour viols deposee contre sebastie...
# Header                                                               france
# Content                   sebastien cauet est vise par une plainte pour ...
# Mentioned_Countries                                        {suisse, france}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 814, dtype: object
# Row 859 updated: Title                     un medaille olympique allemand suspendu 4 ans ...
# Header                                                     hockey sur glace
# Content                   membre du red bull munich, adversaire de genev...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 859, dtype: object
# Row 870 updated: Title                     la prefecture de paris interdit le concert de ...
# Header                                                                  rap
# Content                   freeze corleone au zenith de paris? cest non, ...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 870, dtype: object
# Row 885 updated: Title                     une marche blanche reunit des milliers de pers...
# Header                                                       mort de thomas
# Content                   plusieurs milliers de personnes ont defile en ...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                              {berne}
# Name: 885, dtype: object
# Row 964 updated: Title                     le montreux jazz festival sera meconnaissable ...
# Header                                                   grand demenagement
# Content                   cest un nouveau festival que le public decouvr...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                           {montreux}
# Name: 964, dtype: object
# Row 978 updated: Title                     un systeme numerise pour echanger nos donnees ...
# Header                                                                sante
# Content                   le systeme de sante suisse est bon mais il acc...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                              {berne}
# Name: 978, dtype: object
# Row 999 updated: Title                        les suisses decrochent le bronze aux europeens
# Header                                                              curling
# Content                   lequipe de suisse masculine a remporte la meda...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 999, dtype: object
# Row 1016 updated: Title                            le programme de morges-sous-rire est connu
# Header                                                             festival
# Content                   il y aura du beau monde a morges-sous-rire. le...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                             {morges}
# Name: 1016, dtype: object
# Row 1034 updated: Title                     le nuage qui passe pour un ovni a ete observe ...
# Header                                                montagnes valaisannes
# Content                   oui, a premiere vue, on pourrait croire quun v...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                            {zermatt}
# Name: 1034, dtype: object
# Row 1036 updated: Title                     les concerts de freeze corleone sont finalemen...
# Header                                                                paris
# Content                   a ce soir, a ecrit freeze corleone sur x le 24...
# Mentioned_Countries                                        {suisse, france}
# Mentioned_Swiss_Cities                                             {geneve}
# Name: 1036, dtype: object
# Row 1049 updated: Title                     mathilde gremaud triomphe encore sans faire le...
# Header                                                        ski freestyle
# Content                   ca glisse pour mathilde gremaud sur ce debut d...
# Mentioned_Countries                                                {suisse}
# Mentioned_Swiss_Cities                                              {coire}
# Name: 1049, dtype: object

# %%
city_counts = df_french.explode('Mentioned_Swiss_Cities')['Mentioned_Swiss_Cities'].value_counts()
df_city_counts = pd.DataFrame({'City': city_counts.index, 'Count': city_counts.values})
df_city_counts.sort_values(by='Count', ascending=False, inplace=True)

# %%
df_city_counts
# Out:
#           City  Count
# 0       geneve    101
# 1       zurich     49
# 2        berne     45
# 3     lausanne     44
# 4     fribourg     34
# ..         ...    ...
# 56   schlieren      1
# 55  weinfelden      1
# 54   lenzbourg      1
# 53      horgen      1
# 79    pratteln      1
#
# [80 rows x 2 columns]

# %%
df_city_count_data = df_city_counts.merge(df_cities_french, left_on='City', right_on='Ville', how='left')
df_city_count_data = df_city_count_data[['City', 'Count', 'Coordinates', 'Longitude', 'Latitude']]

# %%
df_city_count_data
# Out:
#           City  Count            Coordinates  Longitude   Latitude
# 0       geneve    101  (47.553808, 7.592036)   7.592036  47.553808
# 1       zurich     49  (46.201511, 6.143889)   6.143889  46.201511
# 2        berne     45  (47.499693, 8.728495)   8.728495  47.499693
# 3     lausanne     44  (46.946416, 7.396394)   7.396394  46.946416
# 4     fribourg     34   (47.10022, 6.825101)   6.825101  47.100220
# ..         ...    ...                    ...        ...        ...
# 75   schlieren      1  (46.462626, 6.842412)   6.842412  46.462626
# 76  weinfelden      1  (47.566894, 9.104073)   9.104073  47.566894
# 77   lenzbourg      1   (47.388748, 8.17853)   8.178530  47.388748
# 78      horgen      1  (47.261948, 8.596927)   8.596927  47.261948
# 79    pratteln      1  (47.518095, 7.689088)   7.689088  47.518095
#
# [80 rows x 5 columns]

# %% [markdown]
# ### Exports

# %%
csv_file_path = 'inputdata/df_countries_french_with_capital_and_coordinates.csv'
df_countries_french.to_csv(csv_file_path, index=False)

# %%
df_countries_french = pd.read_csv('inputdata/df_countries_french_with_capital_and_coordinates.csv')

# %%
df_countries_french
# Out:
#                  Country           Capital ISO2 ISO3             Coordinates  \
# 0    emirats arabes unis         abou dabi   AE  ARE  (24.365909, 54.582942)
# 1                nigeria             abuja   NG  NGA    (9.047364, 7.434935)
# 2                  ghana             accra   GH  GHA   (5.545935, -0.210089)
# 3           turkmenistan          achgabat   TM  TKM       (37.95, 58.38333)
# 4               ethiopie       addis-abeba   ET  ETH   (9.018947, 38.746032)
# ..                   ...               ...  ...  ...                     ...
# 209             cameroun           yaounde   CM  CMR     (3.86667, 11.51667)
# 210                nauru  yaren (de facto)   NR  NRU    (-0.55085, 166.9252)
# 211              croatie            zagreb   HR  HRV  (45.806026, 15.976218)
# 212               kosovo          pristina   XK  NaN    (42.67272, 21.16688)
# 213               taiwan            taipei   TW  TWN   (25.04776, 121.53185)
#
#       Latitude   Longitude
# 0    24.365909   54.582942
# 1     9.047364    7.434935
# 2     5.545935   -0.210089
# 3    37.950000   58.383330
# 4     9.018947   38.746032
# ..         ...         ...
# 209   3.866670   11.516670
# 210  -0.550850  166.925200
# 211  45.806026   15.976218
# 212  42.672720   21.166880
# 213  25.047760  121.531850
#
# [214 rows x 7 columns]

# %%
csv_file_path = 'inputdata/df_temp.csv'
df_countries_french.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_german_with_mentions.csv'
df_german.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_city_count_data_french.csv'
df_city_count_data.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_country_count_data.csv'
df_country_count_data.to_csv(csv_file_path, index=False)

# %%
csv_file_path = 'data/df_translated_country_count_data_french.csv'
df_final_country_count_data.to_csv(csv_file_path, index=False)

# %% [markdown]
# ### Debugs

# %%
test_row = df_german.iloc[0]

# %%
test_row = df_countries_french.iloc[10]
lat, lng = geocode_location_positionstack(test_row['Capital'], geocode_api_key)
print(f"Test - Capital: {test_row['Capital']}, Lat: {lat}, Lng: {lng}")

# %%
test_sentence = "geneve est une belle ville."
doc = nlp(test_sentence)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# geneve LOC

# %%
"geneve" in df_cities_french['Ville'].str.lower().values
# Out:
# True

# %%
def find_countries_in_text_test(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    combined_text = str(content) + " " + str(header)
    doc = nlp(combined_text)
    mentioned_countries = set()

    for ent in doc.ents:
        print("Entity:", ent.text, "Label:", ent.label_)  # Debug print
        if ent.label_ in ['LOC', 'GPE']:
            city_match = ent.text.lower() in swiss_cities_french['Ville'].str.lower().values
            canton_match = ent.text.lower() in swiss_cantons_french['Canton'].str.lower().values
            print("City match:", city_match, "Canton match:", canton_match)  # Debug print

            if city_match or canton_match:
                mentioned_countries.add("suisse")
                continue
            # Rest of the code...

    return mentioned_countries

# %%
temp_df_french = df_french
temp_df_french['Mentioned_Countries'] = temp_df_french.apply(lambda row: find_countries_in_text_test(row['Content'], row['Header'], df_countries_french, df_cities_french, df_cantons_french), axis=1)

# %%
def find_countries_in_text_v2(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    combined_text = str(content) + " " + str(header)
    doc = nlp(combined_text)
    mentioned_countries = set()

    for ent in doc.ents:
        if ent.label_ in ['LOC', 'GPE']:
            entity_parts = ent.text.lower().split()

            for part in entity_parts:
                city_match = part in swiss_cities_french['Ville'].str.lower().values
                canton_match = part in swiss_cantons_french['Canton'].str.lower().values

                if city_match or canton_match:
                    mentioned_countries.add("suisse")
                    break

                    country_from_capital = country_data_french[country_data_french['Capital'].str.lower() == ent.text.lower()]['Country']
            if not country_from_capital.empty:
                mentioned_countries.add(country_from_capital.iloc[0])
                continue

            country = country_data_french[country_data_french['Country'].str.lower() == ent.text.lower()]['Country']
            if not country.empty:
                mentioned_countries.add(country.iloc[0])

    print(f"Final mentioned countries: {mentioned_countries}")  # Debug print
    return mentioned_countries

test_content = "les patins crissent a nouveau au parc des bast à la ville de geneve..."
test_header = "ville de geneve les mesures covid en 2021 puis les restriction..."
print(find_countries_in_text(test_content, test_header, df_countries_french, df_cities_french, df_cantons_french))
# Out:
# Final mentioned countries: {'suisse'}
# {'suisse'}

# %%
temp_df_french
# Out:
#                                                   Title             Header  \
# 0     dix-huit prevenus condamnes dans laffaire du c...  justice francaise
# 1     elle sengage sur lautoroute avec le reservoir ...            argovie
# 2     au portugal, la course au poste de premier min...          politique
# 3     le vote de journalistes, dont celui de la rts,...        ballon d'or
# 4     la premiere ministre refuse de hausser le sala...        bangladesh
# ...                                                 ...                ...
# 1055  une tristesse indescriptible aux obseques de t...             france
# 1056  une voiture en feu a provoque la fermeture du ...                uri
# 1057  la commune voisine de paleo veut negocier des ...        trelex (vd)
# 1058  les patins crissent a nouveau au parc des bast...    ville de geneve
# 1059       vous ne detesterez plus le chou de bruxelles      legume dhiver
#
#                                                 Content  \
# 0     un dessein purement lucratif. dix-huit des 19 ...
# 1     malgre un signal lumineux indiquant que le sto...
# 2     les principaux partis ont commence vendredi a ...
# 3     dans le debat haaland-messi pour le ballon d'o...
# 4     la premiere ministre du bangladesh, sheikh has...
# ...                                                 ...
# 1055  nous taimons et nous ne toublierons jamais. pr...
# 1056  le tunnel routier du gothard est reste ferme d...
# 1057  ces derniers jours, le conseil communal de tre...
# 1058  les mesures covid en 2021 puis les restriction...
# 1059  meme si certains redoutent de le voir dans leu...
#
#                                     Mentioned_Countries
# 0                                 {royaume-uni, france}
# 1                                              {suisse}
# 2                                            {portugal}
# 3     {suisse, liban, panama, bosnie-herzegovine, no...
# 4                                          {bangladesh}
# ...                                                 ...
# 1055                                           {france}
# 1056                                           {suisse}
# 1057                                                 {}
# 1058                                                 {}
# 1059  {suisse, pays-bas, royaume-uni, belgique, france}
#
# [1060 rows x 4 columns]

# %%
# Trying different combinations of content and header
def test_combinations(content, header):
    combinations = [
        content + " " + header,
        content + ". " + header,
        content + "\n" + header
    ]

    for i, combined_text in enumerate(combinations, 1):
        doc = nlp(combined_text)
        print(f"Combination {i}:")
        for ent in doc.ents:
            print(ent.text, ent.label_)
        print("\n")

# Testing with varied combinations
test_combinations(test_content, test_header)
# Out:
# Combination 1:
# parc des bast LOC
# ville de geneve LOC
#
#
# Combination 2:
# parc des bast LOC
#
#
# Combination 3:
# parc des bast LOC
# ville de geneve LOC

# %%
def find_countries_in_text_v2(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    combined_text = str(content) + "\n" + str(header)  # Combine with a newline
    doc = nlp(combined_text)
    mentioned_countries = set()

    for ent in doc.ents:
        if ent.label_ in ['LOC', 'GPE']:
            entity_parts = ent.text.lower().split()  # Split the entity into parts

            for part in entity_parts:
                city_match = part in swiss_cities_french['Ville'].str.lower().values
                canton_match = part in swiss_cantons_french['Canton'].str.lower().values

                if city_match or canton_match:
                    mentioned_countries.add("suisse")
                    break

            # Rest of your original logic...

    return mentioned_countries

# %%
def find_countries_in_text_v2(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    combined_text = str(content) + "\n" + str(header)  # Combine with a newline
    doc = nlp(combined_text)
    mentioned_countries = set()

    for ent in doc.ents:
        if ent.label_ in ['LOC', 'GPE']:
            entity_parts = ent.text.lower().split()  # Split the entity into parts

            for part in entity_parts:
                city_match = part in swiss_cities_french['Ville'].str.lower().values
                canton_match = part in swiss_cantons_french['Canton'].str.lower().values

                if city_match or canton_match:
                    mentioned_countries.add("suisse")  # French for Switzerland
                    break

            # Check if the entity is a capital, then add corresponding country
            country_from_capital = country_data_french[country_data_french['Capital'].str.lower() == ent.text.lower()]['Country']
            if not country_from_capital.empty:
                mentioned_countries.add(country_from_capital.iloc[0])
                continue

            # Check if the entity is a country
            country = country_data_french[country_data_french['Country'].str.lower() == ent.text.lower()]['Country']
            if not country.empty:
                mentioned_countries.add(country.iloc[0])

    return mentioned_countries

# %%
def find_countries_in_text_v2(content, header, country_data_french, swiss_cities_french, swiss_cantons_french):
    combined_text = str(content) + "\n" + str(header)
    doc = nlp(combined_text)
    mentioned_countries = set()

    print(f"Combined Text: {combined_text}")  # Debug print
    for ent in doc.ents:
        print(f"Entity: {ent.text}, Label: {ent.label_}")  # Debug print

        if ent.label_ in ['LOC', 'GPE']:
            entity_parts = ent.text.lower().split()
            for part in entity_parts:
                print(f"Checking part: {part}")  # Debug print

                city_match = part in swiss_cities_french['Ville'].str.lower().values
                canton_match = part in swiss_cantons_french['Canton'].str.lower().values
                print(f"City match: {city_match}, Canton match: {canton_match}")  # Debug print

                if city_match or canton_match:
                    mentioned_countries.add("suisse")
                    break

            # Check if the entity is a capital, then add corresponding country
            country_from_capital = country_data_french[country_data_french['Capital'].str.lower() == ent.text.lower()]['Country']
            if not country_from_capital.empty:
                mentioned_countries.add(country_from_capital.iloc[0])
                continue

            # Check if the entity is a country
            country = country_data_french[country_data_french['Country'].str.lower() == ent.text.lower()]['Country']
            if not country.empty:
                mentioned_countries.add(country.iloc[0])

    return mentioned_countries

# Test the function with the specific text that is causing issues
test_content = "les patins crissent a nouveau au parc des bast..."
test_header = "ville de geneve les mesures covid en 2021 puis les restriction..."
print(find_countries_in_text_v2(test_content, test_header, df_countries_french, df_cities_french, df_cantons_french))
# Out:
# Combined Text: les patins crissent a nouveau au parc des bast...
# ville de geneve les mesures covid en 2021 puis les restriction...
# Entity: parc des bast, Label: LOC
# Checking part: parc
# City match: False, Canton match: False
# Checking part: des
# City match: False, Canton match: False
# Checking part: bast
# City match: False, Canton match: False
# set()
